# %% [markdown]
# Below is a **clean tabular summary** of your entire project so you can quickly recollect what each file does.
#
# ---
#
# ### 📊 Intelligent Device Health Monitoring System
#
# #### 📂 High-Level Architecture Summary
#
# | Layer          | Folder                | Purpose              | What It Does                          | Why It Exists                    |
# | -------------- | --------------------- | -------------------- | ------------------------------------- | -------------------------------- |
# | Data Source    | `data/raw/`           | Source of truth      | Stores original CSV files             | Prevents modifying original data |
# | Processed Data | `data/processed/`     | Cleaned outputs      | Stores engineered features, snapshots | Used for ML & reporting          |
# | Ingestion      | `src/ingestion/`      | Data loading         | Reads raw CSVs                        | Standardizes input data          |
# | Transformation | `src/transformation/` | Relational modeling  | Builds object relationships           | Creates structured data graph    |
# | Health         | `src/health/`         | Health scoring logic | Calculates device/interface health    | Business logic layer             |
# | Features       | `src/features/`       | ML features          | Generates ML-ready features           | Converts raw data → model input  |
# | Models         | `src/models/`         | Machine learning     | Trains & evaluates models             | Intelligence layer               |
# | Inference      | `src/inference/`      | Predictions          | Runs trained models                   | Real-time scoring                |
# | UI             | `app/`                | Streamlit dashboard  | Visualizes system health              | User interaction layer           |
# | Orchestrator   | `main.py`             | Pipeline runner      | Runs full workflow                    | Entry point                      |
#
# ---
#
# ### 📂 Detailed File-Level Summary
#
# #### 🔹 1️⃣ Ingestion Layer
#
# | File           | Role           | Key Function               | Output           |
# | -------------- | -------------- | -------------------------- | ---------------- |
# | `load_data.py` | Raw CSV loader | Reads CSV, renames columns | Clean DataFrames |
#
# Purpose:
#
# > Standardizes messy CSV into consistent format.
#
# ---
#
# ### 🔹 2️⃣ Transformation Layer
#
# #### 📄 `relational_model.py`
#
# | Class          | Represents             | Linked To                               |
# | -------------- | ---------------------- | --------------------------------------- |
# | `Organization` | Company                | Has many Assets                         |
# | `Asset`        | Physical/Logical asset | Belongs to Organization                 |
# | `DeviceClass`  | Device type            | Has many Devices                        |
# | `Device`       | Individual device      | Belongs to Asset & DeviceClass          |
# | `Interface`    | Network interface      | Belongs to Device                       |
# | `Event`        | Device event/log       | Linked to Device (+ optional Interface) |
#
# Purpose:
#
# > Creates in-memory relational graph.
#
# ---
#
# #### 📄 `load_relational_data.py`
#
# | Function               | What It Loads    | Builds                |
# | ---------------------- | ---------------- | --------------------- |
# | `load_organizations()` | organization.csv | Organization objects  |
# | `load_assets()`        | assets.csv       | Asset objects         |
# | `load_devices()`       | devices.csv      | Device objects        |
# | `load_interfaces()`    | interfaces.csv   | Interface objects     |
# | `load_events()`        | events.csv       | Event objects         |
# | `load_all_data()`      | All above        | Full relational graph |
#
# Purpose:
#
# > Converts CSV → Object Model → Linked Structure
#
# ---
#
# #### 🔹 3️⃣ Health Layer
#
# | File                    | Purpose                                    | Output          |
# | ----------------------- | ------------------------------------------ | --------------- |
# | `health_scoring.py`     | Computes health score per device/interface | Health score    |
# | `window_aggregation.py` | Time-window aggregation (1h, 24h, 7d)      | Rolling metrics |
#
# Purpose:
#
# > Converts raw events into meaningful health indicators.
#
# ---
#
# #### 🔹 4️⃣ Feature Engineering Layer
#
# | File                     | Purpose                                | Output            |
# | ------------------------ | -------------------------------------- | ----------------- |
# | `feature_engineering.py` | Converts health + events → ML features | Feature DataFrame |
#
# Example features:
#
# * Event count last 24h
# * Error ratio
# * Interface downtime frequency
# * Health score trend
#
# ---
#
# #### 🔹 5️⃣ Model Layer
#
# | File                    | Model Type        | Purpose                         |
# | ----------------------- | ----------------- | ------------------------------- |
# | `anomaly_detection.py`  | Unsupervised      | Detect abnormal behavior        |
# | `failure_prediction.py` | Supervised        | Predict device failure          |
# | `train.py`              | Training pipeline | Train and save models           |
# | `evaluate.py`           | Evaluation        | Accuracy, ROC, confusion matrix |
#
# Purpose:
#
# > Adds intelligence to system.
#
# ---
#
# #### 🔹 6️⃣ Inference Layer
#
# | File         | Purpose                                  |
# | ------------ | ---------------------------------------- |
# | `predict.py` | Loads trained models & predicts new data |
#
# Used for:
#
# * Dashboard scoring
# * Real-time inference
# * Batch predictions
#
# ---
#
# #### 🔹 7️⃣ Utilities
#
# | File        | Purpose                |
# | ----------- | ---------------------- |
# | `logger.py` | Central logging system |
#
# Used by all modules.
#
# ---
#
# ### 🔹 8️⃣ UI Layer
#
# #### 📄 `device_health_app.py`
#
# | Section              | What It Does             |
# | -------------------- | ------------------------ |
# | Loads processed data | Displays system status   |
# | Shows device health  | Shows event distribution |
# | Allows filtering     | Drilldown into devices   |
#
# Purpose:
#
# > Makes system user-friendly.
#
# ---
#
# ### 🔹 9️⃣ Notebook Layer
#
# #### 📄 `exploratory_analysis.ipynb`
#
# | Section                  | Purpose                    |
# | ------------------------ | -------------------------- |
# | Relationship exploration | Validates relational model |
# | Distribution plots       | Understand data            |
# | Event trends             | Identify patterns          |
# | Aggregation validation   | Verify correctness         |
#
# Purpose:
#
# > Analytical exploration & validation.
#
# ---
#
# ### 🔹 🔟 Main Entry Point
#
# #### 📄 `main.py`
#
# | Step                | What It Runs         |
# | ------------------- | -------------------- |
# | Ingestion           | Load data            |
# | Transformation      | Build relationships  |
# | Health scoring      | Compute health       |
# | Feature engineering | Generate ML features |
# | Train models        | Fit ML               |
# | Evaluate            | Validate models      |
#
# Purpose:
#
# > Runs full pipeline end-to-end.
#
# ---
#
# ### 🧠 Entire System in One Mental Diagram
#
# ```text
# Raw CSVs
#    ↓
# Ingestion
#    ↓
# Relational Model
#    ↓
# Health Scoring
#    ↓
# Feature Engineering
#    ↓
# ML Models
#    ↓
# Inference
#    ↓
# Streamlit Dashboard
# ```
#
# ---
#
# ### 🎯 Quick Recollection Version (Ultra-Short)
#
# | Layer          | One-Line Memory Trigger |
# | -------------- | ----------------------- |
# | Ingestion      | Read CSV                |
# | Transformation | Build object graph      |
# | Health         | Calculate device score  |
# | Features       | Prepare ML input        |
# | Models         | Train intelligence      |
# | Inference      | Predict health/failure  |
# | UI             | Visualize system        |
# | Main           | Run everything          |
#
# ---
